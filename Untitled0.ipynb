# %% [markdown]
# <a href="https://colab.research.google.com/github/miguelorduna360-alt/Debt/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.feature_selection import SelectKBest
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error, accuracy_score

# %% [markdown]
# Data Exploration: DEBT

# %%
url = "https://docs.google.com/spreadsheets/d/1P60l_6YnoY1pBKoN6JG2dx33_kX6TftV/export?format=csv&gid=567854546"
debt_df = pd.read_csv(url)
debt_df.head()
# Out:
#    Unnamed: 0                                         Unnamed: 1 Unnamed: 2  \
# 0         NaN  Source: Mbaye, S., Moreno-Badia, M., and K. Ch...        NaN
# 1         NaN                    Last Update: December 16, 2019.        NaN
# 2         NaN                                                NaN        NaN
# 3         NaN                               Global Debt Database        NaN
# 4         NaN  The Global Debt Database (GDD) is the result o...        NaN
#
#   Unnamed: 3
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
